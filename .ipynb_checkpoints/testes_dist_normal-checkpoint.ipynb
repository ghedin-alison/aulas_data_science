# %%
# Testes de distribuição normal

# %%
# Importação de bibliotecas
from scipy import stats
from scipy.stats import norm, skewnorm
import matplotlib.pyplot as plt

# %%
# Criação de uma variavel com dados em uma distribuição normal com a função rvs(100 elementos)
dados = norm.rvs(size = 1000)

# %%
# histograma
plt.hist(dados, bins = 20)
plt.title('Dados')
# Out:
# Text(0.5, 1.0, 'Dados')

# %%
# Geração de gráfico para verificar se a distribuição é normal(kickplot)
fig, ax = plt.subplots()
stats.probplot(dados, fit=True, plot=ax)
plt.show()

# %%
# Execução do teste de Shapiro
# Segundo argumento é o valor de p, se (pvalue) > 0.05, não há como rejeitar a hipotese nula(é a hipotese de que os dados estão normalmente distribuidos)
stats.shapiro(dados)
# Out:
# ShapiroResult(statistic=0.998906672000885, pvalue=0.82133549451828)

# %%
# Dados não normais

# %%
dados2 = skewnorm.rvs(4, size = 1000) # skewnorm cria dados não normais

# %%
# Geração de gráfico para verificar se a distribuição é normal(kickplot)
fig, ax = plt.subplots()
stats.probplot(dados2, fit=True, plot=ax)
plt.show()

# %%
stats.shapiro(dados2)
pvalue > 1.01
# Out:
# ShapiroResult(statistic=0.9608636498451233, pvalue=1.0136181758369747e-15)
